# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'name': ['hongildong', 'hongeeedong', 'hongsamdong'],
    'math': [90, 80, 70],
    'eng': [98, 89, 95],
    'music': [85, 95, 100],
    'phys_tra': [100, 90, 90]
})

# %%
df
# Out:
#           name  math  eng  music  phys_tra
# 0   hongildong    90   98     85       100
# 1  hongeeedong    80   89     95        90
# 2  hongsamdong    70   95    100        90

# %%
df.set_index('name', inplace=True)

# %%
df.index
# Out:
# Index(['hongildong', 'hongeeedong', 'hongsamdong'], dtype='object', name='name')

# %%
df
# Out:
#              math  eng  music  phys_tra
# name
# hongildong     90   98     85       100
# hongeeedong    80   89     95        90
# hongsamdong    70   95    100        90

# %%
df.iloc[0]
# Out:
# math         90
# eng          98
# music        85
# phys_tra    100
# Name: hongildong, dtype: int64

# %%
df.iloc[[0]]
# Out:
#             math  eng  music  phys_tra
# name
# hongildong    90   98     85       100

# %%
c = df.loc['hongildong', ['math', 'music']]

# %%
c
# Out:
# math     90
# music    85
# Name: hongildong, dtype: int64

# %%
df.iloc[0, [2, 3]]
# Out:
# music        85
# phys_tra    100
# Name: hongildong, dtype: int64

# %%
df.iloc[0, [0, 2]]
# Out:
# math     90
# music    85
# Name: hongildong, dtype: int64

# %%
df.loc['hongildong', 'math':'phys_tra']
# Out:
# math         90
# eng          98
# music        85
# phys_tra    100
# Name: hongildong, dtype: int64

# %%
df.iloc[1, 1:]
# Out:
# eng         89
# music       95
# phys_tra    90
# Name: hongeeedong, dtype: int64

# %%
df.iloc[1, 1:]
# Out:
# eng         89
# music       95
# phys_tra    90
# Name: hongeeedong, dtype: int64

# %%
df.loc[['hongildong', 'hongeeedong'], ['music', 'phys_tra']]
# Out:
#              music  phys_tra
# name
# hongildong      85       100
# hongeeedong     95        90

# %%
df.iloc[[1, 2], [1, 3]]
# Out:
#              eng  phys_tra
# name
# hongeeedong   89        90
# hongsamdong   95        90

# %%
df.iloc[1:, 1:]
# Out:
#              eng  music  phys_tra
# name
# hongeeedong   89     95        90
# hongsamdong   95    100        90

# %%
df['kor']=80

# %%
df
# Out:
#              math  eng  music  phys_tra  kor
# name
# hongildong     90   98     85       100   80
# hongeeedong    80   89     95        90   80
# hongsamdong    70   95    100        90   80

# %%
df.loc[df.index[1], 'kor'] = 95

# %%
df
# Out:
#              math  eng  music  phys_tra  kor
# name
# hongildong     90   98     85       100   80
# hongeeedong    80   89     95        90   95
# hongsamdong    70   95    100        90   80

# %%
df = df.reset_index()

# %%
df
# Out:
#           name  math  eng  music  phys_tra  kor
# 0   hongildong    90   98     85       100   80
# 1  hongeeedong    80   89     95        90   95
# 2  hongsamdong    70   95    100        90   80

# %%
df[3] = 0

# %%
df
# Out:
#           name  math  eng  music  phys_tra  kor  3
# 0   hongildong    90   98     85       100   80  0
# 1  hongeeedong    80   89     95        90   95  0
# 2  hongsamdong    70   95    100        90   80  0

# %%
df.set_index('name', inplace=True)

# %%
df
# Out:
#              math  eng  music  phys_tra  kor  3
# name
# hongildong     90   98     85       100   80  0
# hongeeedong    80   89     95        90   95  0
# hongsamdong    70   95    100        90   80  0

# %%
df[3] = 0

# %%
df
# Out:
#              math  eng  music  phys_tra  kor  3
# name
# hongildong     90   98     85       100   80  0
# hongeeedong    80   89     95        90   95  0
# hongsamdong    70   95    100        90   80  0

# %%
df.drop(3, axis=1, inplace=True)

# %%
df
# Out:
#              math  eng  music  phys_tra  kor
# name
# hongildong     90   98     85       100   80
# hongeeedong    80   89     95        90   95
# hongsamdong    70   95    100        90   80

# %%
df.loc[3] = 0

# %%
df
# Out:
#              math  eng  music  phys_tra  kor
# name
# hongildong     90   98     85       100   80
# hongeeedong    80   89     95        90   95
# hongsamdong    70   95    100        90   80
# 3               0    0      0         0    0

# %%
df.drop(3, axis=0, inplace=True)

# %%
df
# Out:
#              math  eng  music  phys_tra  kor
# name
# hongildong     90   98     85       100   80
# hongeeedong    80   89     95        90   95
# hongsamdong    70   95    100        90   80

# %%
df.index = ['stud1', 'stud2', 'stud3']

# %%
df
# Out:
#        math  eng  music  phys_tra  kor   name
# stud1    90   98     85       100   80  stud1
# stud2    80   89     95        90   95  stud2
# stud3    70   95    100        90   80  stud3

# %%
dft = df.transpose()

# %%
dft
# Out:
#           stud1  stud2  stud3
# math         90     80     70
# eng          98     89     95
# music        85     95    100
# phys_tra    100     90     90
# kor          80     95     80
# name      stud1  stud2  stud3

# %%
dft.T
# Out:
#       math eng music phys_tra kor   name
# stud1   90  98    85      100  80  stud1
# stud2   80  89    95       90  95  stud2
# stud3   70  95   100       90  80  stud3

# %%
dict_data = {f'c{i}':[3*i + k+1 for k in range(3)] for i in range(5)}

# %%
df2 = pd.DataFrame(dict_data)

# %%
df2.index = ['r1', 'r2', 'r3']

# %%
df2 = df2.reset_index()

# %%
df2
# Out:
#   index  c0  c1  c2  c3  c4
# 0    r1   1   4   7  10  13
# 1    r2   2   5   8  11  14
# 2    r3   3   6   9  12  15

# %%
df2 = df2.reset_index()

# %%
df2 = df2.drop('level_0', axis=1)

# %%
df2 = df2.set_index('index')

# %%
df2
# Out:
#        c0  c1  c2  c3  c4
# index
# r1      1   4   7  10  13
# r2      2   5   8  11  14
# r3      3   6   9  12  15

# %%
df2.sort_index()
# Out:
#        c0  c1  c2  c3  c4
# index
# r1      1   4   7  10  13
# r2      2   5   8  11  14
# r3      3   6   9  12  15

# %%
df2.sort_index(ascending=False)
# Out:
#        c0  c1  c2  c3  c4
# index
# r3      3   6   9  12  15
# r2      2   5   8  11  14
# r1      1   4   7  10  13

# %%
df2.sort_values(by='c2')
# Out:
#        c0  c1  c2  c3  c4
# index
# r1      1   4   7  10  13
# r2      2   5   8  11  14
# r3      3   6   9  12  15

# %%
student1 = pd.Series({'kor': 100, 'eng': 80, 'math': 90})

# %%
student1
# Out:
# kor     100
# eng      80
# math     90
# dtype: int64

# %%
student1/100
# Out:
# kor     1.0
# eng     0.8
# math    0.9
# dtype: float64

# %%
df
# Out:
#        math  eng  music  phys_tra  kor   name
# stud1    90   98     85       100   80  stud1
# stud2    80   89     95        90   95  stud2
# stud3    70   95    100        90   80  stud3

# %%
student1 = df.iloc[0].drop('name')
student2 = df.iloc[1].drop('name')
student3 = df.iloc[2].drop('name')

# %%
student1 + student2
# Out:
# math        170
# eng         187
# music       180
# phys_tra    190
# kor         175
# dtype: object

# %%
student3['music'] = np.nan

# %%
average = (student1 + student2 + student3)/3

# %%
average
# Out:
# math             80.0
# eng              94.0
# music             NaN
# phys_tra    93.333333
# kor              85.0
# dtype: object

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
