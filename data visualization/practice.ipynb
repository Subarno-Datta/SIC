# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
boston = pd.read_csv('data_boston.csv')
census = pd.read_csv('data_census.csv')
coffee = pd.read_csv('data_coffeeshop.csv')
sales = pd.read_csv('data_sales.csv')
studentlist = pd.read_csv('data_studentlist.csv')

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
census
# Out:
#      Province Code  City Code    Population   Households  Person's Household  \
# 0              109       1001   10,078,850    4,197,478                 2.40
# 1              109       1188      155,695       72,882                 2.14
# 2              109       1189      126,817       59,614                 2.13
# 3              109       1158      235,186      108,138                 2.17
# 4              109       1105      298,145      126,915                 2.35
# ..             ...        ...           ...          ...                 ...
# 276            103       1011       63,069       27,724                 2.27
# 277            103       1233       48,856       24,193                 2.02
# 278            115       1001      615,250      251,478                 2.45
# 279            115       1186      454,673      182,709                 2.49
# 280            115       1096      160,577       68,769                 2.34
#
#      Gender Ratio
# 0            0.97
# ...

# %%
coffee
# Out:
#        Year of Start Current State  Size of Site
# 0             2008.0            In         20.80
# 1             2010.0            In        212.72
# 2             2013.0            In         20.04
# 3             2012.0            In         64.17
# 4             2002.0           Out         11.40
# ...              ...           ...           ...
# 43177         2014.0           Out         30.61
# 43178         2011.0            In         44.21
# 43179         2013.0            In         35.70
# 43180         2011.0           Out         46.20
# 43181         2014.0            In        176.49
#
# [43182 rows x 3 columns]

# %%
sales
# Out:
#          Date   Region     Item  Unit Price  Units
# 0   04-Jul-14     East  Pen Set        4.99     62
# 1   12-Jul-14     East   Binder        1.99     29
# 2   21-Jul-14  Central  Pen Set       12.49     55
# 3   29-Jul-14     East   Binder       19.99     81
# 4   07-Aug-14  Central  Pen Set       23.95     42
# 5   15-Aug-14     East   Pencil        4.99     35
# 6   24-Aug-14     West     Desk      275.00      3
# 7   01-Sep-14  Central     Desk      125.00      2
# 8   10-Sep-14  Central   Pencil        1.29      7
# 9   18-Sep-14     East  Pen Set       15.99     16
# 10  27-Sep-14     West      Pen        1.99     76
# 11  05-Oct-14  Central   Binder        8.99     28
# 12  14-Oct-14     West   Binder       19.99     57
# 13  22-Oct-14     East      Pen        8.99     64
# 14  31-Oct-14  Central   Pencil        1.29     14
# 15  08-Nov-14     East      Pen       19.99     15
# 16  17-Nov-14  Central   Binder        4.99     11
# ...

# %%
studentlist
# Out:
#                 Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# ...
