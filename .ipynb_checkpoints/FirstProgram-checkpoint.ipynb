# %%
import random

# %%
for i in range(20):
    x = random.randint(10, 20)
    print(x)
# Out:
# 12
# 12
# 14
# 20
# 17
# 11
# 10
# 18
# 10
# 20
# 18
# 19
# 17
# 11
# 14
# 16
# 14
# 19
# 12
# 14

# %% [markdown]
# <!-- write a program to open a csv file and convert it to a pandas dataframe -->

# %%
num = float(input("enter a number: "))
# Out:
# enter a number:  17.356

# %%
abso = lambda x: x if x>0 else -x

# %%
# Out:
# 0.5
